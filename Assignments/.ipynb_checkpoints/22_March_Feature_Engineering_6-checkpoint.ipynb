# %% [markdown]
# # Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %% [markdown]
# ![Screenshot%20from%202023-08-15%2016-46-24.png](attachment:Screenshot%20from%202023-08-15%2016-46-24.png)

# %%
import numpy as np

# Sample data
time_spent_studying = [5, 10, 8, 12, 7]
exam_scores = [75, 90, 82, 95, 80]

# Calculate means
mean_time = np.mean(time_spent_studying)
mean_scores = np.mean(exam_scores)

# Calculate Pearson correlation coefficient
numerator = sum((time - mean_time) * (score - mean_scores) for time, score in zip(time_spent_studying, exam_scores))
denominator_time = np.sqrt(sum((time - mean_time)**2 for time in time_spent_studying))
denominator_scores = np.sqrt(sum((score - mean_scores)**2 for score in exam_scores))
correlation_coefficient = numerator / (denominator_time * denominator_scores)

print("Pearson Correlation Coefficient:", correlation_coefficient)
# Out:
# Pearson Correlation Coefficient: 0.9946730655543622

# %% [markdown]
# # Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.

# %%
import pandas as pd
# Sample data
sleep_hours = [7, 6, 8, 5, 7]
job_satisfaction = [9, 6, 8, 4, 7]
df = pd.DataFrame({
    'sleep_hours':sleep_hours,
    'job_satisfaction':job_satisfaction
})
df.corr(method='spearman')
# Out:
#                   sleep_hours  job_satisfaction
# sleep_hours          1.000000          0.820783
# job_satisfaction     0.820783          1.000000

# %% [markdown]
# # Q3. Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.

# %%
#sample data
exercise_hours = [4, 6, 3, 7, 5, 2, 5, 3, 4, 6, 1, 2, 3, 5, 6, 7, 2, 1, 3, 4,
                  5, 6, 7, 4, 3, 2, 1, 5, 6, 4, 3, 2, 5, 6, 7, 4, 3, 2, 1,
                  5, 6, 4, 3, 2, 1, 5, 4, 3, 2, 1]
bmi = [25.5, 23.8, 30.2, 22.6, 26.7, 29.1, 24.8, 28.4, 26.9, 23.7,
       31.5, 32.7, 28.9, 25.6, 24.1, 21.5, 29.3, 30.9, 27.8, 25.3,
       23.6, 22.1, 20.4, 26.0, 27.6, 30.8, 31.1, 25.2, 24.7, 26.3,
       28.2, 29.7, 23.2, 22.8, 20.1, 26.6, 28.5, 29.9, 31.2, 24.6,
       23.9, 21.3, 27.1, 30.3, 28.7, 26.4, 24.3, 25.9, 23.4, 27.5]
df = pd.DataFrame({
    'exercise_hours':exercise_hours,
    'bmi':bmi
})
df
print(f"Pearson correlation coefficient:{df.corr(method='pearson').iloc[0][1]}")
print(f"Spearman's rank correlation: {df.corr(method='spearman').iloc[0][1]}")
# Out:
# Pearson correlation coefficient:-0.8571492379923363
# Spearman's rank correlation: -0.8570883868872707

# %% [markdown]
# # Q4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between these two variables.

# %%
#sample data
tv_hours = [3, 2, 4, 5, 1, 2, 4, 3, 6, 2, 1, 3, 4, 5, 6, 3, 2, 1, 4, 5,
            6, 2, 3, 4, 1, 5, 6, 3, 2, 1, 4, 5, 6, 3, 2, 1, 4, 5, 6, 3,
            2, 1, 4, 5, 6, 3, 2, 1, 4, 5]
physical_activity = [30, 45, 20, 15, 60, 45, 25, 30, 10, 40, 50, 35,
                     25, 15, 10, 30, 45, 60, 20, 15, 10, 50, 30, 25,
                     55, 10, 15, 20, 30, 45, 60, 25, 15, 10, 30, 45,
                     60, 20, 30, 45, 15, 25, 10, 40, 20, 30, 15, 25,
                     10, 35]
df=pd.DataFrame({
    'tv_hours':tv_hours,
    'physical_activity':physical_activity
})
df.corr(method='pearson')
# Out:
#                    tv_hours  physical_activity
# tv_hours           1.000000          -0.581036
# physical_activity -0.581036           1.000000

# %% [markdown]
# # Q5. A survey was conducted to examine the relationship between age and preference for a particular brand of soft drink. The survey results are shown below:
#
# |Age(Years)|Soft drink Preference|
# |-|-|
# | 24 | Coke |
# |-|-|
# | 42 | Pepsi |
# |-|-|
# | 37 | Mountain dew |
# |-|-|
# | 19 | Coke |
# |-|-|
# | 31 | Pepsi |
# |-|-|
# | 28 | Coke |

# %% [markdown]
# # Q6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %%
import numpy as np
from scipy.stats import pearsonr

# Sample data
sales_calls_per_day = [20, 25, 15, 30, 18, 24, 17, 22, 28, 21,
                       19, 23, 26, 16, 27, 20, 25, 15, 30, 18,
                       24, 17, 22, 28, 21, 19, 23, 26, 16, 27]
sales_per_week = [8, 10, 6, 12, 7, 9, 6, 10, 13, 8,
                  7, 11, 11, 6, 12, 8, 10, 6, 12, 7,
                  9, 6, 10, 13, 8, 7, 11, 11, 6, 12]

# Calculate Pearson correlation coefficient
corr_coefficient, _ = pearsonr(sales_calls_per_day, sales_per_week)

print("Pearson Correlation Coefficient:", corr_coefficient)
# Out:
# Pearson Correlation Coefficient: 0.9510310309693629

# %%
# Sample data
sales_calls_per_day = [20, 25, 15, 30, 18, 24, 17, 22, 28, 21,
                       19, 23, 26, 16, 27, 20, 25, 15, 30, 18,
                       24, 17, 22, 28, 21, 19, 23, 26, 16, 27]
sales_per_week = [8, 10, 6, 12, 7, 9, 6, 10, 13, 8,
                  7, 11, 11, 6, 12, 8, 10, 6, 12, 7,
                  9, 6, 10, 13, 8, 7, 11, 11, 6, 12]
df = pd.DataFrame({
    'sales_calls_per_day':sales_calls_per_day,
    'sales_per_week':sales_per_week
})
df.corr('pearson')
# Out:
#                      sales_calls_per_day  sales_per_week
# sales_calls_per_day             1.000000        0.951031
# sales_per_week                  0.951031        1.000000
