# %%
pip install bokeh
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting bokeh
#   Downloading bokeh-3.6.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh) (3.1.5)
# Requirement already satisfied: contourpy>=1.2 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh) (2.2.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh) (24.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh) (6.4.2)
# Collecting xyzservices>=2021.09.1 (from bokeh)
#   Downloading xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asits\appdata\roaming\python\python313\site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asits\appdata\roaming\python\python313\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asits\appdata\roaming\python\python313\site-packages (from pandas>=1.2->bokeh) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asits\appdata\roaming\python\python313\site-packages (from pandas>=1.2->bokeh) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\asits\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)
# Downloading bokeh-3.6.3-py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --------------------------- ------------ 4.7/6.9 MB 25.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.0/6.9 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 926.4 kB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 925.0 kB/s eta 0:00:00
# Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Installing collected packages: xyzservices, bokeh
# Successfully installed bokeh-3.6.3 xyzservices-2025.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install bokeh_sampledata
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting bokeh_sampledata
#   Downloading bokeh_sampledata-2024.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting icalendar (from bokeh_sampledata)
#   Downloading icalendar-6.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas>=1.2 in c:\users\asits\appdata\roaming\python\python313\site-packages (from bokeh_sampledata) (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asits\appdata\roaming\python\python313\site-packages (from pandas>=1.2->bokeh_sampledata) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asits\appdata\roaming\python\python313\site-packages (from pandas>=1.2->bokeh_sampledata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asits\appdata\roaming\python\python313\site-packages (from pandas>=1.2->bokeh_sampledata) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asits\appdata\roaming\python\python313\site-packages (from pandas>=1.2->bokeh_sampledata) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\asits\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh_sampledata) (1.17.0)
# Downloading bokeh_sampledata-2024.2-py3-none-any.whl (17.6 MB)
#    ---------------------------------------- 0.0/17.6 MB ? eta -:--:--
#    ----- ---------------------------------- 2.6/17.6 MB 15.0 MB/s eta 0:00:01
#    ------------- -------------------------- 6.0/17.6 MB 13.8 MB/s eta 0:00:01
#    --------------------------- ------------ 12.1/17.6 MB 18.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 15.7/17.6 MB 20.3 MB/s eta 0:00:01
#    ---------------------------------------  17.6/17.6 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------  17.6/17.6 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------- 17.6/17.6 MB 12.7 MB/s eta 0:00:00
# Downloading icalendar-6.1.1-py3-none-any.whl (200 kB)
# Installing collected packages: icalendar, bokeh_sampledata
# Successfully installed bokeh_sampledata-2024.2 icalendar-6.1.1

# %%
import bokeh.io
import bokeh.plotting

# %%
#run this render your graph inside the jupyter notebook
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d418a426-a9d0-4148-8d84-961c2d1ff8cf">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure , output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('resources/test_bokeh.html')

#creating canvas
p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.circle(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div id="e963f11f-e1a1-45cd-bc21-6a99189feded" data-root-id="p1001" style="display: contents;"></div>

# %%
output_file('test.html')

p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div id="a8b10c23-52a6-4a01-a3c3-04b40e55ce4e" data-root-id="p1145" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line graph")
p.line(x,y)
show(p)
# Out:
#   <div id="b8833dd9-c462-4f47-bffa-97f837a40618" data-root-id="p1193" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line graph")
p.scatter(x,y , size = 20,fill_color = ['red','blue','1DECE0','orange','green'],legend_label = 'this is my data point')
show(p)
# Out:
#   <div id="dbf40fda-3618-489f-a6f0-dd55843288c8" data-root-id="p1237" style="display: contents;"></div>
