# %%
import bokeh.io
import bokeh.plotting

# %%
#run this render your graph inside the jupyter notebook
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e2c6c988-0ec1-4687-bf9c-d75fa4d30326">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure , output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('resources/test_bokeh.html')

#creating canvas
p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.circle(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div id="ed814b00-b3bd-42bb-9328-356f70bae1dc" data-root-id="p1192" style="display: contents;"></div>

# %%
output_file('test.html')

p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div id="e66d4e2d-02df-48ab-ba61-dc3bd13e9e9d" data-root-id="p1192" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line graph")
p.line(x,y)
show(p)
# Out:
#   <div id="e1764150-61b2-4948-a9a8-247440abda88" data-root-id="p1428" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line graph")
p.scatter(x,y , size = 20,fill_color = ['red','blue','1DECE0','orange','green'],legend_label = 'this is my data point')
show(p)
# Out:
#   <div id="e2e2ee7a-925a-4aa1-8cda-bc57701eefce" data-root-id="p4116" style="display: contents;"></div>
