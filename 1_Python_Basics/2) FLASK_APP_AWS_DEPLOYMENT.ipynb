# %% [markdown]
# ![Screenshot%202023-04-06%20144852.png](attachment:Screenshot%202023-04-06%20144852.png)

# %% [markdown]
# **STEP1**:- PUSING THE ENTIRE CODE INTO GITHUB<BR>
# >  on cmd line/terminal use commands:-
#
#
# **STEP2**:- FROM GITHUB PUSH THE ENTIRE CODE TO A CODE PIPELINE <BR>
# **STEP3**:- FROM CODE PIPELINE DO DEPLOYMENT USING BEAN STAK(BEAN STACK PROVIDES A CPU, RAM, HARD DISK FOR DEPLOYMENT)

# %%
# Out:
# 'LS' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
