# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
url = "https://www.flipkart.com/search?q="+"tv"

#Requesting http response as an object from flipkart using urlopen()
http_response=urlopen(url)

# %%
ugly_page=http_response.read()
http_response.close()

# %% [markdown]
# ![Screenshot%202023-03-25%20125130.png](attachment:Screenshot%202023-03-25%20125130.png)
# If showing this output this means the after reading once the cursor has moved to end of the line so run http response again

# %%
#beautifying the above html dump
flipkart_beauty = bs(ugly_page,"html.parser")
flipkart_beauty
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ### getting 1st tv informations

# %%
#complte url fror the 1st tv box
"https://www.flipkart.com"+"/huidi-80-cm-32-inch-hd-ready-led-tv-bezel-less-display/p/itm980181eae4bd7?pid=TVSG5FP3VQXJJZBS&lid=LSTTVSG5FP3VQXJJZBSUEN4NU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_Yb3Oi078hOs329KezCEwOv9Iy9HDdw%2FHXIaj2qsO7pU57fVUJPcCRz7S0%2BU34bTQ%2Fom%2FnhUJTvUChCksh2qNDw%3D%3D&ppt=hp&ppn=homepage&ssid=t9nqrxwdvk0000001679728632390&qH=c9a1fdac6e082dd8"
#objective is to automate this for all the boxes
# Out:
# 'https://www.flipkart.com/huidi-80-cm-32-inch-hd-ready-led-tv-bezel-less-display/p/itm980181eae4bd7?pid=TVSG5FP3VQXJJZBS&lid=LSTTVSG5FP3VQXJJZBSUEN4NU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_Yb3Oi078hOs329KezCEwOv9Iy9HDdw%2FHXIaj2qsO7pU57fVUJPcCRz7S0%2BU34bTQ%2Fom%2FnhUJTvUChCksh2qNDw%3D%3D&ppt=hp&ppn=homepage&ssid=t9nqrxwdvk0000001679728632390&qH=c9a1fdac6e082dd8'

# %%
#finding all the div classes of tv boxes
bigboxes = flipkart_beauty.find_all("div",{"class":"_1AtVbE col-12-12"})
len(bigboxes)
# Out:
# 30

# %%
del bigboxes[0:1]

# %%
# extracting url from big boxes
bigboxes[3].div.div.div.a["href"]
# Out:
# '/oneplus-y1-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio/p/itme650a6bb8cee3?pid=TVSFVWD2ENXYGEJY&lid=LSTTVSFVWD2ENXYGEJYBNWSST&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=c71623f6-f9ca-494d-a5f4-5902dca6a43c.TVSFVWD2ENXYGEJY.SEARCH&ppt=None&ppn=None&ssid=v86sg88u1s0000001680162651674&qH=c9a1fdac6e082dd8'

# %%
#append this url with "https://www.flipkart.com" then we will get full link for box 1
"https://www.flipkart.com"+bigboxes[3].div.div.div.a["href"]
# Out:
# 'https://www.flipkart.com/oneplus-y1-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio/p/itme650a6bb8cee3?pid=TVSFVWD2ENXYGEJY&lid=LSTTVSFVWD2ENXYGEJYBNWSST&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=c71623f6-f9ca-494d-a5f4-5902dca6a43c.TVSFVWD2ENXYGEJY.SEARCH&ppt=None&ppn=None&ssid=v86sg88u1s0000001680162651674&qH=c9a1fdac6e082dd8'

# %%
#automating the above process of scrapping the url of all the boxes
for i in bigboxes:
    print("https://www.flipkart.com"+i.div.div.div.a["href"])
# Out:
# https://www.flipkart.com/thomson-9r-pro-108-cm-43-inch-ultra-hd-4k-led-smart-android-tv/p/itm7d6c8b8019530?pid=TVSG6TJEFQMUSQTE&lid=LSTTVSG6TJEFQMUSQTEMGLF9Z&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_jXSs26xVpKUtJCsz8LprnHXEmsy6Uv%2FTlR5c0eStQfdbSY%2FWdmyZI%2BiMXujZ%2F5K1SGLNBKl6UEZzh9JoC%2FUrjw%3D%3D&ppt=None&ppn=None&ssid=yfq73wpwrk0000001679730406392&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/samsung-80-cm-32-inch-hd-ready-led-smart-tizen-tv-2022-model/p/itm3c07ddc2dd25d?pid=TVSGHY2UZA9YHWQN&lid=LSTTVSGHY2UZA9YHWQNNQENTU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_jXSs26xVpKUtJCsz8LprnHXEmsy6Uv%2FTlR5c0eStQfc0OnrOtDwhatoY17CaS%2FBWKUXLsS6xKC1eMMA2CJL5Kg%3D%3D&ppt=None&ppn=None&ssid=yfq73wpwrk0000001679730406392&qH=c9a1fdac6e082dd8
# ...

# %% [markdown]
# **above 'NoneType' error we will handel in exception handeling**

# %%
#now visualizing scrapping of reviews from 1st prodect link
prod_url= "https://www.flipkart.com"+bigboxes[0].div.div.div.a["href"]
req_prod = requests.get(prod_url,"html.parser")
req_prod.text #converts get request into a text string
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.103f43.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %%
#beautifying the above data
prod_beauty = bs(req_prod.text)

# %%
#extracting person_name,comment,rating,reviews
cmmt_box = prod_beauty.find_all("div",{"class":"_16PBlm"})
cmmt_box
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Delightful</p></div><div class="row"><div class="t-ZTKy"><div><div class="">The picture quality is crisp n delight to eyes.the sound is pretty loud so I prefer lesser volunteer me to avoid disturbing neighbours. The apps running smoothly .  The casting is smooth too with Hout any hassle or lag.<br/>At present happy with purchase n time will tell the durability of the product. <br/>Now enjoying the TV.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">RAAKEYSH. S</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="re
# ...

# %%
cmmt_box[0].div.div.find_all("p","_2sc7ZR _2V5EHH")[0].text
# Out:
# 'RAAKEYSH. S'

# %%
#print all commenter's name
for i in cmmt_box:
    print(i.div.div.find_all("p","_2sc7ZR _2V5EHH")[0].text)
# Out:
# RAAKEYSH. S
# Naveen Upadhyay
# Idris Khan
# Vishvesh Rawal
# Flipkart Customer
# Ramakrishnan K
# Vineet Tyagi
# Chaitanya Karvir
# Vinod Kumar
# Khemraj Bairwa
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15004\3977425157.py in <module>
#       1 #print all commenter's name
#       2 for i in cmmt_box:
# ----> 3     print(i.div.div.find_all("p","_2sc7ZR _2V5EHH")[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#print all the ratings
for i in cmmt_box:
    print("Rating:-{},    Name:-{},   comment:-{}".format(i.div.div.div.div.text, i.div.div.find_all("p","_2sc7ZR _2V5EHH")[0].text, i.div.div.div.p.text))
# Out:
# Rating:-4,    Name:-RAAKEYSH. S,   comment:-Delightful
# Rating:-5,    Name:-Naveen Upadhyay,   comment:-BEST 4K SMART ANROID TV
# Rating:-5,    Name:-Idris Khan,   comment:-Pretty good
# Rating:-1,    Name:-Vishvesh Rawal,   comment:-Don't waste your money
# Rating:-5,    Name:-Flipkart Customer,   comment:-Worth every penny
# Rating:-4,    Name:-Ramakrishnan K,   comment:-Delightful
# Rating:-5,    Name:-Vineet Tyagi,   comment:-Just wow!
# Rating:-5,    Name:-Chaitanya Karvir,   comment:-Best in the market!
# Rating:-2,    Name:-Vinod Kumar,   comment:-Could be way better
# Rating:-5,    Name:-Khemraj Bairwa,   comment:-Must buy!worh of every penny great 4k experiance
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15004\3471279042.py in <module>
#       1 #print all the ratings
#       2 for i in cmmt_box:
# ...

# %%
#Extracting comments
for i in cmmt_box:
    print(i.div.div.find_all("div",{"class":""})[0].text)
# Out:
# The picture quality is crisp n delight to eyes.the sound is pretty loud so I prefer lesser volunteer me to avoid disturbing neighbours. The apps running smoothly .  The casting is smooth too with Hout any hassle or lag.At present happy with purchase n time will tell the durability of the product. Now enjoying the TV.READ MORE
# It is really a value for money. This is a 4K latest Anroid Smart TV just launched, TV is working fine with very high picture quality and the USP of this smart anroid TV is that it contains 40 W speakers which are really fantastic.It contains lots of ports including HDMI, USB and LAN ports. You can cromcast your mobile screen directly to your TV screen. It contains Google voice assist function on its remote fromwhere you can just speak and all is reflected on your screen.It's really a valu...READ MORE
# ...

# %% [markdown]
# ### Q1. Write a python program to extract the video URL of the first five videos.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time

# %%
def main():
    driver = webdriver.Chrome()
    driver.get('https://www.youtube.com/@PW-Foundation/videos')
    # time.sleep(10)
    content = driver.page_source.encode('utf-8').strip()
    soup = bs(content,'html.parser')
    #print(soup)
    titles = soup.find_all('a',{'id':'video-title-link'})
    print(titles)
    #print(len(titles))
    #for title in titles:
        #print(title.text)
main()
# Out:
# []

# %%
def main():
    driver = webdriver.Chrome()
    driver.get('https://www.youtube.com/@PW-Foundation/videos')
    # time.sleep(10)
    content = driver.page_source.encode('utf-8').strip()
    soup = bs(content,'html.parser')
    titles = soup.find_all('a',{'id':'video-title-link'})
    views = soup.find_all('span',{'class':'inline-metadata-item style-scope ytd-video-meta-block'})
    video_urls = soup.find_all('a',{'id':'video-title-link'})
    #print(video_urls[0]['href']
    i=0
    j=0
    for title in titles[:5]:
        print(f"title:{title.text}, Views:{views[j].text}, URL:{video_urls[i]['href']}")
        i+=1
        j+=2
main()
# Out:
# title:Best Way To Start Class -9th English 💥 || Master Strategy Plan || Follow this ⚡⚡, Views:7.7K views, URL:/watch?v=33onjejJLDs
# title:PWSAT Is Back Again!! 🔥 || India's Biggest Scholarship Test || Watch This ⚡⚡, Views:12K views, URL:/watch?v=o3eOj-jhhfI
# title:Finally The Wait is Over 🔥 || Icse Batch Coming Soon || Must Watch 🔥🔥, Views:20K views, URL:/watch?v=ecGcmstmnGA
# title:Best Strategy To Start Class-9th SST || Don't Miss This Video🛑 || Complete Roadmap, Views:19K views, URL:/watch?v=08WWij66k8A
# title:Finally The Wait is Over🔥 || Launching Foundation Channels in 5 Different Languages 🤩, Views:30K views, URL:/watch?v=bXpeyKIVioA

# %%
def main():
    driver = webdriver.Chrome()
    driver.get('https://www.youtube.com/@PW-Foundation/videos')
    # time.sleep(10)
    content = driver.page_source.encode('utf-8').strip()
    soup = bs(content,'html.parser')
    #titles = soup.find_all('a',{'id':'video-title-link'})
    views = soup.find_all('span',{'class':'inline-metadata-item style-scope ytd-video-meta-block'})
    #print(views)
    for view in views:
        print(view.text)
    #video_urls = soup.find_all('a',{'id':'video-title-link'})
    #print(video_urls[0]['href']
main()
# Out:
# 7.7K views
# 1 day ago
# 12K views
# 3 days ago
# 20K views
# 8 days ago
# 19K views
# 10 days ago
# 30K views
# 2 weeks ago
# 61K views
# 2 weeks ago
# 121K views
# 2 weeks ago
# 22K views
# 2 weeks ago
# 87K views
# 2 weeks ago
# 37K views
# 2 weeks ago
# 39K views
# 2 weeks ago
# 268K views
# 3 weeks ago
# 50K views
# 3 weeks ago
# 47K views
# 3 weeks ago
# 74K views
# 3 weeks ago
# 63K views
# 4 weeks ago
# 80K views
# 4 weeks ago
# 98K views
# 4 weeks ago
# 80K views
# 4 weeks ago
# 59K views
# 1 month ago
# 73K views
# 1 month ago
# 146K views
# 1 month ago
# 429K views
# 1 month ago
# 70K views
# 1 month ago
# 37K views
# 1 month ago
# 46K views
# 1 month ago
# 29K views
# 1 month ago
# 26K views
# 1 month ago
# 67K views
# 1 month ago
# 75K views
# 1 month ago
